# %%
import numpy as np
import glob
import time
import dataset as dt

# %%
pathlist = []
for filepath in glob.iglob("./DataTheory/*.txt"):
    pathlist.append(str(filepath))
mydatasets= dt.Datasets(pathlist, False)
# Out:
# Reading file from  :  ./DataTheory/5946.txt
#          X      Q2    Y     data   theory  totError  totErrorUncor  chi2Naive  \
# 0    0.125   4.104  0.7  0.49030  0.45892   0.03134        0.02390    1.00291
# 1    0.175   4.104  0.5  0.71490  0.60587   0.04379        0.02903    6.19834
# 2    0.175   4.925  0.6  0.56210  0.46864   0.03655        0.02559    6.53892
# 3    0.175   5.745  0.7  0.40450  0.35986   0.02715        0.02199    2.70394
# 4    0.225   4.221  0.4  0.78240  0.66506   0.04245        0.03022    7.64267
# ..     ...     ...  ...      ...      ...       ...            ...        ...
# 407  0.550  52.622  0.3  0.10570  0.12949   0.03102        0.02980    0.58798
# 408  0.550  70.162  0.4  0.07472  0.09065   0.02682        0.02618    0.35288
# 409  0.650  41.460  0.2  0.07909  0.07555   0.02315        0.02149    0.02337
# 410  0.650  62.189  0.3  0.07290  0.05233   0.02502        0.02115    0.67584
# ...

# %%
mydatasets.plotX_Q2_Coverage()
# Out:
# Dataset with X and Q2 kinetic variables :  [5946, 5948, 5160, 5114, 5942, 5159, 5125, 5138, 5116, 5944, 5156, 5161, 5112, 5135, 5203, 5121, 5945, 5949, 106, 5139, 5947, 105, 5158, 5124, 5201, 5132, 5943, 5101, 5205, 5123, 5141, 5140, 5206, 5113, 5108, 5131, 5102, 5104, 5204, 5157, 5122, 5103, 5129, 5120, 5105, 5126, 5202, 5136, 5106, 5137, 5127, 5115, 5143, 5119, 5107, 5111]

# %%
mydatasets.plotChi2Dof()
